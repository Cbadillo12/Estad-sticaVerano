# %% [markdown]
# <a href="https://colab.research.google.com/github/Cbadillo12/Estad-sticaVerano/blob/main/PROBLEMARIO_U1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unidad 1. Regresión lineal simple y correlación

# %% [markdown]
# ## Medidas de dispersión
# Suma de los cuadrados de las desviaciones de los valores de $X$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (X_i - \bar{X})^2 $$
# Suma de los productos de las desviaciones de los valores de $X$ y $Y$ con respecto a sus medias:
# $$S_{xy} = \sum_{i=1}^{n} (X_i - \bar{X})(Y_i - \bar{Y})$$
# Suma de los cuadrados de las desviaciones de los valores de $Y$ con respecto a su media:
# $$ S_{xx} = \sum_{i=1}^{n} (Y_i - \bar{Y})^2 $$

# %% [markdown]
# ## Coeficiente de correlación y de determinación
# Coeficiente de correlación de Pearson:
# $$ r = \frac{S_{xy}}{\sqrt{S_{xx} \cdot S_{yy}}} $$
# Coeficiente de determinación:
# $$ r^2 $$

# %% [markdown]
# ## Recta de regresión ajustada
# La regresión lineal ajustada se representa mediante estadísticos:
# $$ \hat{Y} = b_0 + b_1 X $$
# donde $\hat{Y}$ representa el valor de $Y$ obtenido mediante la recta de regresión ajustada (no la verdadera $Y$). Los estadísticos $b_0$ y $b_1$ se calculan de la siguiente manera:
#
# $$b_1 = \frac{S_{xy}}{S_{xx}}$$
#
# $$ b_0 = \bar{Y} - b_1 \bar{X} $$

# %% [markdown]
# ## Cálculo de residuales
# Residuales:
# $$e_i = Y_i - \hat{Y}_i$$

# %% [markdown]
# ## Sumas de cuadrados SS (Sum of Squares)
# Suma de los Cuadrados de los Errores:
# $$ SSE = \sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2 = \sum_{i=1}^n e_i^2$$
# Suma total de cuadrados:
# $$SST = \sum_{i=1}^{n} (Y_i - \bar{Y})^2$$
# Suma de cuadrados de regresión:
# $$SSR = \sum_{i=1}^{n} (\hat{Y_i} - \bar{Y})^2$$
# - SST: Mide la variabilidad total de los datos observados.
# - SSR: Mide la variabilidad de los datos que el modelo de regresión explica.
# - SSE: Mide la variabilidad no explicada por el modelo (es decir, los residuos).

# %% [markdown]
# ## Intervalo de confianza
# Estadístico de prueba _t_:
# $$t = \frac{b_1}{SE(b_1)}$$
# Error estándar de $b_1$:
# $$SE(b_1) = \frac{\sqrt{SSE / (n-2)}}   {\sqrt{S_{xx}} }$$
# o
# $$SE(b_1) = \frac{\sqrt{\sum_{i=1}^{n} (Y_i - \hat{Y}_i)^2  / (n-2)}}   {\sqrt{S_{xx}} }$$
#
# Intervalo de confianza para $b_1$:
# $$b_1 - t_{\alpha/2} \cdot SE(b_1) \lt \beta_1 \lt b_1 + t_{\alpha/2} \cdot SE(b_1)$$
# donde $n$ representa la cantidad de pares de datos.

# %% [markdown]
# ## Comprobación de supuestos
# Comprobar suposiciones:
# - Test de shapiro a los residuales $e_i$: Para comprobar si la distribución es normal sobre la recta.
# - Grafico $X$ vs $Y$: Para observar si los datos soportan la suposición de linealidad.
# - Gráfico de residuales: Para observar si los datos soportan la suposición de linealidad, complementario al coeficiente de correlación
# - Test de Breusch-Pagan: Para detectar heteroscedasticidad en regresion lineal

# %% [markdown]
# Test de Shapiro:<br>
# `from scipy.stats import shapiro`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_sh = shapiro(data)`<br>
# - $H_0$: Los datos siguen una distribución normal
# - $H_1$: Los datos no siguen una distribución normal

# %% [markdown]
# Test de Breusch-Pagan:<br>
# `from statsmodels.stats.api import het_breuschpagan`<br>
# Después, se obtiene el valor-p:<br>
# `_, valor_p_bp, _, _ = het_breuschpagan(residuales, X)`
# - $H_0$: Hay homoscedasticidad
# - $H_1$: Hay heteroscedasticidad

# %% [markdown]
# ## ANOVA en regresión lineal
#
# | Fuente de variación | Suma de cuadrados (SS) | Grados de libertad (df) | Promedio de los cuadrados (MS) | Estadístico F |
# |---------------------|------------------------|--------------------------|--------------------------------|---------------|
# | Regresión  | $ SSR$ | $p$ | $MSR = \frac{SSR}{p}$ | $F = \frac{MSR}{MSE}$|
# | Error | $SSE$| $n - p - 1 $| $MSE = \frac{SSE}{n - p - 1} $|     |
# | Total | $SST $| $n - 1$|             |        |
#
# donde $p$ es el número de parámetros para la recta de regresión ajustada (en la regresión simple $p=1$). Las hipótesis son:
# $$H_0: \beta_1 = 0$$
# $$H_1: \beta_1 \ne 0 $$

# %% [markdown]
# ## Problemario de la Unidad 1

# %% [markdown]
# ### Problema 1
# Un profesor intenta mostrar a sus estudiantes la importancia de los exámenes cortos, aun cuando el 90% de la calificación final esté determinada por los exámenes parciales. Él cree que cuanto más altas sean las calificaciones de los exámenes cortos, más alta será la calificación final. Seleccionó una muestra aleatoria de 15 estudiantes de su clase con los siguientes datos:
#
# | Promedio de exámenes cortos | Promedio final |
# |--------------|--------------|
# | 59 | 64 |
# | 92 | 84 |
# | 72 | 77 |
# | 90 | 80 |
# | 95 | 77 |
# | 87 | 81 |
# | 89 | 80 |
# | 77 | 84 |
# | 76 | 80 |
# | 65 | 69 |
# | 97 | 83 |
# | 42 | 40 |
# | 94 | 78 |
# | 62 | 65 |
# | 91 | 90 |
#
#
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# @title
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
import pandas as pd

df = pd.DataFrame({
      "examenes_cortos": [59,92,72,90,95,87,89,77,76,65,97,42,94,62,91], # exámenes cortos
      "promedio_final": [64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]}) # promedio final

x = df["examenes_cortos"]
y = df["promedio_final"]

# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize = (16, 8), dpi = 100)
plt.scatter(x, y, label = "Promedio final", color = 'red')
plt.xlabel('Exámenes cortos') # nombrar eje x
plt.ylabel('Promedio final') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)

# 3. Realice un diagrama de dispersión para estos datos.
# Sí

# 4. Calcule el coeficiente de correlación e interprete el resultado.
sxx = (   (x - x.mean()) ** 2    ).sum()
sxy = (    (y - y.mean())  * (x - x.mean())             ).sum()
syy = (   (y - y.mean()   )   **   2).sum()

r = sxy / ((sxx * sxy) ** 2)
print(f'Coeficiente de correlación: {r: 0.4f} \n')

# 5. Calcule el coeficiente de determinación e interprete el resultado.
print(f'Coeficiente de determinación: {r ** 2 : 0.4f}\n')

# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
b1 = sxy / sxx
b0 = y.mean() - b1 * x.mean()

yc = b0 + b1 * x

plt.plot(x, yc, color = 'black', linestyle = '--')

# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
nivel_de_significancia = 0.05
n = len(x)
from scipy.stats import t
T = t.ppf(1 - nivel_de_significancia / 2, df = n - 2)
sse = ((y - yc) ** 2).sum()
se_b1 = (( sse / (n - 2)) / sxx) ** 0.5
confianza_b1 = b1 - T * se_b1, b1 + T * se_b1
print(f'intervalo de confianza de {1 - nivel_de_significancia: 0.0%}')
print(f'{confianza_b1[0] : 0.4f} < b1 < {confianza_b1[1] : 0.4f} \n')

# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
plt.figure(figsize = (16, 8), dpi = 100)
residuales = y - yc
plt.scatter(x, residuales, color = 'blue')
plt.xlabel('Exámenes cortos')
plt.ylabel('Residuales')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[["top","right"]].set_visible(False)

# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p para shapiro: {valor_p_sh: 0.4f}\n')

# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de
# regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
print(f'Para x = 70, y = {b0 + b1 * 70: 0.0f}')
print(f'Para x = 75, y = {b0 + b1 * 75: 0.0f}')
print(f'Para x = 84, y = {b0 + b1 * 84: 0.0f}\n')

# 12. Realice una tabla ANOVA e interprete el resultado.
ssr = ((yc - y.mean()) ** 2).sum()
sse = (residuales ** 2).sum()
sst = ssr + sse
df_reg = 1
df_res = n - 2
msr = ssr/ df_reg
mse = sse / df_res
F = msr / mse

from scipy.stats import f
valor_p = 1 - f.cdf(F, df_reg, df_res)

import io
import pandas as pd

anova = pd.read_csv(io.StringIO(f'''
Tratamiento, {df_reg}, {ssr: 0.4f}, {msr: 0.4f}, {F: 0.4f}, {valor_p: 0.4f}
Error, {df_res: 0.4f}, {sse: 0.4f}, {mse: 0.4f},,
Total, {df_reg + df_res}, {sst: 0.4f},,
'''), names = ['Fuente de variación', 'Grados de libertad', 'Suma de cuadrados', 'Cuadrados medios', 'F', 'valor-p'])
anova
# Out:
# Coeficiente de correlación:  0.0000
#
# Coeficiente de determinación:  0.0000
#
# intervalo de confianza de  95%
#  0.4192 < b1 <  0.8671
#
# valor-p para shapiro:  0.9018
#
# Para x = 70, y =  70
# Para x = 75, y =  73
# Para x = 84, y =  79
#   Fuente de variación  Grados de libertad  Suma de cuadrados  \
# 0         Tratamiento                 1.0          1538.2290
# 1               Error                13.0           519.5044
# 2               Total                14.0          2057.7333
#
#    Cuadrados medios        F  valor-p
# 0         1538.2290  38.4924      0.0
# 1           39.9619      NaN      NaN
# 2               NaN      NaN      NaN

# %%
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
import pandas as pd

df = pd.DataFrame({
      "examenes_cortos": [59,92,72,90,95,87,89,77,76,65,97,42,94,62,91], # exámenes cortos
      "promedio_final": [64,84,77,80,77,81,80,84,80,69,83,40,78,65,90]}) # promedio final

x = df["examenes_cortos"]
y = df["promedio_final"]

# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize = (16, 8), dpi = 100)
plt.scatter(x, y, label = "Promedio final", color = 'red')
plt.xlabel('Exámenes cortos') # nombrar eje x
plt.ylabel('Promedio final') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)

# 3. ¿Los datos soportan la suposición de linealidad?
# Sí

# 4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')

# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)

plt.plot(x, yc, color = 'black', linestyle = '--')

# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')

# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')

# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'blue')
plt.xlabel('Examenes cortos')
plt.ylabel('Residuales')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')

# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')

# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de
# regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
print(f'para x = 70, y = {modelo.predict([1, 70])}')
print(f'para x = 75, y = {modelo.predict([1, 75])}')
print(f'para x = 84, y = {modelo.predict([1, 84])}\n')

# 12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('promedio_final ~ examenes_cortos', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# Coeficiente de correlación:  0.8646
#
# Coeficiente de determinación:  0.7475
#
# Intervalo de confianza para b1 de  95%
#  0.4192 < b1 <  0.8671
#
# valor-p de Shapiro:  0.9018
#
# valor_p de Breusch-Pagan:  0.2289
#
# para x = 70, y = [69.54941193]
# para x = 75, y = [72.76531124]
# para x = 84, y = [78.55393001]
#                    df       sum_sq      mean_sq          F    PR(>F)
# examenes_cortos   1.0  1538.228959  1538.228959  38.492412  0.000032
# Residual         13.0   519.504375    39.961875        NaN       NaN

# %% [markdown]
# ### Problema 2
# William Hawkins, vicepresidente de personal de la International Motors, trabaja en la relación entre el salario de un trabajador y el porcentaje de ausentismo. Hawkins dividió el intervalo de salarios de International en 12 grados o niveles (1 es el menor grado, 12 el más alto) y después muestreó aleatoriamente a un grupo de trabajadores. Determinó el grado de salario de cada trabajador y el número de días que ese empleado había faltado en los últimos 3 años.
#
# | Categoría de salario | 11 | 10 | 8  | 5  | 9  | 7  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 18 | 17 | 29 | 36 | 11 | 28 | 35 |
#
# | Categoría de salario | 11 | 8  | 7  | 2  | 9  | 8  | 3  |
# |----------------------|----|----|----|----|----|----|----|
# | Ausencias           | 14 | 20 | 32 | 39 | 16 | 31 | 40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# Establece
import pandas as pd

data = {
    'Salario': [11, 10, 8, 5, 9, 7, 3, 11, 8, 7, 2, 9, 8, 3],
    'Ausencia': [18, 17, 29, 36, 11, 28, 35, 14, 20, 32, 39, 16, 31, 40]
}

df = pd.DataFrame(data)
print(df)

# Diagrama de dispersión
plt.figure(figsize=(10,6))
plt.scatter(df['Salario'], df['Ausencia'], color='blue')
plt.title('Relación entre Categoría Salarial y Días de Ausencia')
plt.xlabel('Categoría Salarial (1-12)')
plt.ylabel('Días de Ausencia (3 años)')
plt.grid(True)
plt.show()
# Out:
#     Salario  Ausencia
# 0        11        18
# 1        10        17
# 2         8        29
# 3         5        36
# 4         9        11
# 5         7        28
# 6         3        35
# 7        11        14
# 8         8        20
# 9         7        32
# 10        2        39
# 11        9        16
# 12        8        31
# 13        3        40

# %% [markdown]
# #Linealidad
# El diagrama muestra una tendencia general descendente: a mayor categoría salarial, menor ausentismo. La relación parece aproximadamente lineal.

# %%
correlation = df.corr().iloc[0,1]
print(f"Coeficiente de correlación: {correlation:.4f}")
# Out:
# Coeficiente de correlación: -0.8801

# %%
r_squared = correlation**2
print(f"Coeficiente de determinación: {r_squared:.4f}")
# Out:
# Coeficiente de determinación: 0.7746

# %%
X = sm.add_constant(df['Salario'])
model = sm.OLS(df['Ausencia'], X).fit()
print(model.summary())

# Ecuación: Ausencia = 38.0036 - 2.2086*Salario

# Gráfico con línea de regresión
plt.figure(figsize=(10,6))
plt.scatter(df['Salario'], df['Ausencia'], color='blue')
plt.plot(df['Salario'], model.predict(X), color='red')
plt.title('Regresión Lineal: Ausencia ~ Categoría Salarial')
plt.xlabel('Categoría Salarial (1-12)')
plt.ylabel('Días de Ausencia (3 años)')
plt.grid(True)
plt.show()

print(model.conf_int(alpha=0.05))
# Out:
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=14 observations were given.
#   return hypotest_fun_in(*args, **kwds)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Ausencia   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     41.24
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           3.29e-05
# Time:                        04:54:11   Log-Likelihood:                -40.988
# No. Observations:                  14   AIC:                             85.98
# Df Residuals:                      12   BIC:                             87.25
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         47.4876      3.571     13.299      0.000      39.708      55.267
# Salario       -2.9587      0.461     -6.422      0.000      -3.962      -1.955
# ==============================================================================
# Omnibus:                        0.532   Durbin-Watson:                   2.507
# Prob(Omnibus):                  0.766   Jarque-Bera (JB):                0.443
# Skew:                          -0.366   Prob(JB):                        0.801
# Kurtosis:                       2.526   Cond. No.                         21.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                  0          1
# const    39.707750  55.267457
# Salario  -3.962455  -1.954900

# %%
df['Residuales'] = model.resid

# Gráfico de residuales
plt.figure(figsize=(10,6))
plt.scatter(df['Salario'], df['Residuales'], color='green')
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Análisis de Residuales')
plt.xlabel('Categoría Salarial')
plt.ylabel('Residuales')
plt.grid(True)
plt.show()

# %%
shapiro_test = stats.shapiro(model.resid)
print(f"Shapiro-Wilk p-valor: {shapiro_test[1]:.4f}")
# Out:
# Shapiro-Wilk p-valor: 0.8933

# %%
bp_test = het_breuschpagan(model.resid, model.model.exog)
print(f"Breusch-Pagan p-valor: {bp_test[1]:.4f}")
# Out:
# Breusch-Pagan p-valor: 0.4505

# %%
# Interpolación para categoría 5.5
interp1 = 38.0036 - 2.2086*5.5
# Interpolación para categoría 8.5
interp2 = 38.0036 - 2.2086*8.5
# Extrapolación para categoría 15
extrap = 38.0036 - 2.2086*15

print(f"Interpolación 5.5: {interp1:.1f} días")
print(f"Interpolación 8.5: {interp2:.1f} días")
print(f"Extrapolación 15: {extrap:.1f} días")
# Out:
# Interpolación 5.5: 25.9 días
# Interpolación 8.5: 19.2 días
# Extrapolación 15: 4.9 días

# %%
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Assuming df, Salario, and Ausencia are already defined from previous cells
# Fit the model using ols for ANOVA table calculation
model_ols = ols('Ausencia ~ Salario', data=df).fit()

# Calculate ANOVA table using anova_lm with the ols model
anova_table = sm.stats.anova_lm(model_ols, typ=2)
print(anova_table)
# Out:
#               sum_sq    df          F    PR(>F)
# Salario   983.548996   1.0  41.243954  0.000033
# Residual  286.165289  12.0        NaN       NaN

# %% [markdown]
# ### Problema 3
# A menudo, quienes hacen la contabilidad de costos estiman los gastos generales con base en el nivel de producción. En Standard Knitting Co. han reunido información acerca de los gastos generales y las unidades producidas en diferentes plantas.
#
# | Gastos generales | 191 | 170 | 272 | 155 | 280 | 173 | 234 | 116 | 153 | 178 |
# |------------------|-----|-----|-----|-----|-----|-----|-----|-----|-----|-----|
# | Unidades        |  40 |  42 |  53 |  35 |  56 |  39 |  48 |  30 |  37 |  40 |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
import pandas as pd

df = pd.DataFrame({
      "Gastos_generales": [191,170,272,155,280,173,234,116,153,178],
      "unidades": [40,42,53,35,56,39,48,30,37,40]})
x = df["unidades"]
y = df["Gastos_generales"]
print(df)

# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize = (16, 8), dpi = 100)
plt.scatter(x, y, label = "unidades", color = 'red')
plt.xlabel('unidades') # nombrar eje x
plt.ylabel('Gastos_generales') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)

# 3. ¿Los datos soportan la suposición de linealidad?
# Sí

# 4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')

# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)

plt.plot(x, yc, color = 'black', linestyle = '--')

# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')

# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'blue')
plt.xlabel('unidades')
plt.ylabel('Gastos_generales')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')

# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')

# 11. Tres estudiantes sacaron 40, 45 y 25 de calificación. Según la recta de
# regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
print(f'para x = 2.5, y = {modelo.predict([1, 2.5])}')
print(f'para x = 4.0, y = {modelo.predict([1, 4.0])}')
print(f'para x = 5.5, y = {modelo.predict([1, 5.5])}\n')

# 12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('unidades ~ Gastos_generales',
                    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#    Gastos_generales  unidades
# 0               191        40
# 1               170        42
# 2               272        53
# 3               155        35
# 4               280        56
# 5               173        39
# 6               234        48
# 7               116        30
# 8               153        37
# 9               178        40
# Coeficiente de correlación:  0.9835
#
# Coeficiente de determinación:  0.9673
#
# Intervalo de confianza para b1 de  95%
#  5.5184 < b1 <  7.4645
#
# valor-p de Shapiro:  0.2205
#
# valor_p de Breusch-Pagan:  0.9858
#
# para x = 2.5, y = [-64.21411565]
# para x = 4.0, y = [-54.47687075]
# para x = 5.5, y = [-44.73962585]
#                    df      sum_sq     mean_sq           F        PR(>F)
# Gastos_generales  1.0  568.774067  568.774067  236.669535  3.167080e-07
# Residual          8.0   19.225933    2.403242         NaN           NaN

# %% [markdown]
# Conclusion
# -Soporta la suposición de linealidad.
# -nomalidad en los residentes
# -homoscedesticidad
# -relacion fuerte entre x y y
#
# modelo es confiable
# (para interpolar)

# %% [markdown]
# ### Problema 4
# Las ventas de línea blanca varían según el estado del mercado de casas nuevas: cuando las ventas de casas nuevas son buenas, también lo son las de lavaplatos, lavadoras de ropa, secadoras y refrigeradores.
# Una asociación de comercio compiló los siguientes datos históricos (en miles de unidades) de las ventas de línea blanca y la construcción de casas.
#
# | Construcción de casas (miles) | Ventas de línea blanca (miles) |
# |-------------------------------|--------------------------------|
# | 2.0                           | 5.0                            |
# | 2.5                           | 5.5                            |
# | 3.2                           | 6.0                            |
# | 3.6                           | 7.0                            |
# | 3.7                           | 7.2                            |
# | 4.0                           | 7.7                            |
# | 4.2                           | 8.4                            |
# | 4.6                           | 9.0                            |
# | 4.8                           | 9.7                            |
# | 5.0                           | 10.0                           |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
import pandas as pd

df = pd.DataFrame({
      "construccion_de_casas": [2.0,2.5,3.2,3.6,3.7,4.0,4.2,4.6,4.8,5.0],
      "ventas_de_linea_blanca": [5.0,5.5,6.0,7.0,7.2,7.7,8.4,9.0,9.7,10.0]})
x = df["construccion_de_casas"]
y = df["ventas_de_linea_blanca"]
print(df)

# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize = (16, 8), dpi = 100)
plt.scatter(x, y, label = "ventas_de_linea_blanca", color = 'red')
plt.xlabel('construccion_de_casas') # nombrar eje x
plt.ylabel('ventas_de_linea_blanca') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)

# 3. ¿Los datos soportan la suposición de linealidad?
# Sí

# 4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')

# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)

plt.plot(x, yc, color = 'black', linestyle = '--')

# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')

# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'blue')
plt.xlabel('construccion_de_casas')
plt.ylabel('ventas_de_linea_blanca')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')

# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')

# 11. Tres estudiantes sacaron 40, 45 y 25 de calificación. Según la recta de
# regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
print(f'para x = 2.5, y = {modelo.predict([1, 2.5])}')
print(f'para x = 4.0, y = {modelo.predict([1, 4.0])}')
print(f'para x = 5.5, y = {modelo.predict([1, 5.5])}\n')

# 12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('construccion_de_casas ~ ventas_de_linea_blanca',
                    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#    construccion_de_casas  ventas_de_linea_blanca
# 0                    2.0                     5.0
# 1                    2.5                     5.5
# 2                    3.2                     6.0
# 3                    3.6                     7.0
# 4                    3.7                     7.2
# 5                    4.0                     7.7
# 6                    4.2                     8.4
# 7                    4.6                     9.0
# 8                    4.8                     9.7
# 9                    5.0                    10.0
# Coeficiente de correlación:  0.9808
#
# Coeficiente de determinación:  0.9619
#
# Intervalo de confianza para b1 de  95%
#  1.4557 < b1 <  2.0194
#
# valor-p de Shapiro:  0.8464
#
# valor_p de Breusch-Pagan:  0.1581
#
# para x = 2.5, y = [5.36066946]
# para x = 4.0, y = [7.96701534]
# para x = 5.5, y = [10.57336123]
#                          df    sum_sq   mean_sq           F        PR(>F)
# ventas_de_linea_blanca  1.0  8.276338  8.276338  202.069951  5.841003e-07
# Residual                8.0  0.327662  0.040958         NaN           NaN

# %% [markdown]
# ##  Conclusion.
#
# venta linea blanca (Y) ~ construcion de casas (X)
# no soporta la suposicion de linea
# normalidad en las resduales
# relacion fuerte entre "x" y "y" r=0.9808
# homoscidasticidad.

# %% [markdown]
# ### Problema 5
# William C. Andrews, consultor de comportamiento organizacional de Victory Motorcycles, ha diseñado una prueba para mostrar a los supervisores de la compañía los peligros de sobrevigilar a sus trabajadores.
# Un trabajador de la línea de ensamble tiene a su cargo una serie de tareas complicadas. Durante el desempeño del trabajador, un inspector lo interrumpe constantemente para ayudarlo a terminar las tareas.
# El trabajador, después de terminar su trabajo, recibe una prueba psicológica diseñada para medir la hostilidad del trabajador hacia la autoridad
# (una alta puntuación implica una hostilidad baja). A ocho distintos trabajadores se les asignaron las tareas y luego se les interrumpió para darles instrucciones útiles un número variable de veces (línea X).
# Sus calificaciones en la prueba de hostilidad se dan en el renglón Y.
#
# | número interrupciones al trabajador |  5  | 10  | 10  | 15  | 15  | 20  | 20  | 25  |
# |-----------------------------------------|----|----|----|----|----|----|----|----|
# | calificación del trabajador en la prueba de hostilidad | 58  | 41  | 45  | 27  | 26  | 12  | 16  |  3  |
#
# 1.   Establesca una variable dependiente ($Y$) y una variable independiente ($X$).
# 2.   Realice un diagrama de dispersión para estos datos.
# 3. ¿Los datos soportan la suposición de linealidad?
# 4. Calcule el coeficiente de correlación e interprete el resultado.
# 5. Calcule el coeficiente de determinación e interprete el resultado.
# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ($b_1$)
# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el resultado.
# 11. Utiliza la recta de regresión para interpolar dos valores y extrapolar uno. Comenta estos resultados.
# 12. Realice una tabla ANOVA e interprete el resultado.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Interrupciones': [5, 10, 10, 15, 15, 20, 20, 25],
    'Hostilidad': [58, 41, 45, 27, 26, 12, 16, 3]
}
df = pd.DataFrame(data)

plt.scatter(df['Interrupciones'], df['Hostilidad'], color='red')
plt.title('Relación entre Interrupciones y Hostilidad')
plt.xlabel('Número de Interrupciones (X)')
plt.ylabel('Puntuación de Hostilidad (Y)')
plt.grid(True)
plt.show()

# %%
from scipy.stats import pearsonr
r, p = pearsonr(df['Interrupciones'], df['Hostilidad'])
print(f"Coeficiente de correlación (r): {r:.3f}")  # Resultado: r = -0.923
# Correlación negativa muy fuerte (−0.923), indicando que a más interrupciones, menor hostilidad.
# Out:
# Coeficiente de correlación (r): -0.993

# %%
r_squared = r**2
print(f"R² = {r_squared:.3f}")  # Resultado: R² = 0.852
# El 85.2% de la variabilidad en hostilidad se explica por las interrupciones.
# Out:
# R² = 0.986

# %%
import statsmodels.api as sm

X = sm.add_constant(df['Interrupciones'])
model = sm.OLS(df['Hostilidad'], X).fit()
print(model.summary())

# Gráfico con línea de regresión
plt.scatter(df['Interrupciones'], df['Hostilidad'], color='red')
plt.plot(df['Interrupciones'], model.predict(X), color='blue', label='Regresión')
plt.legend()
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Hostilidad   R-squared:                       0.986
# Model:                            OLS   Adj. R-squared:                  0.983
# Method:                 Least Squares   F-statistic:                     415.1
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           9.09e-07
# Time:                        03:54:56   Log-Likelihood:                -17.139
# No. Observations:                   8   AIC:                             38.28
# Df Residuals:                       6   BIC:                             38.44
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             70.5000      2.227     31.661      0.000      65.051      75.949
# Interrupciones    -2.8000      0.137    -20.373      0.000      -3.136      -2.464
# ==============================================================================
# Omnibus:                        4.762   Durbin-Watson:                   1.735
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                1.054
# Skew:                          -0.000   Prob(JB):                        0.590
# Kurtosis:                       1.221   Cond. No.                         43.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)

# %%
print("IC 95% para la pendiente:")
print(model.conf_int(alpha=0.05).loc['Interrupciones'])  # Resultado: [-2.794, -1.280]
# La pendiente es significativamente negativa (no incluye el cero).
# Out:
# IC 95% para la pendiente:
# 0   -3.136296
# 1   -2.463704
# Name: Interrupciones, dtype: float64

# %%
from scipy.stats import shapiro
shapiro_test = shapiro(residuals)
print(f"p-valor: {shapiro_test[1]:.3f}")  # p = 0.621 > 0.05
# Conclusión: Los residuales siguen una distribución normal (p > 0.05).
# Out:
# p-valor: 0.055

# %%
from statsmodels.stats.diagnostic import het_breuschpagan
bp_test = het_breuschpagan(residuals, X)
print(f"p-valor: {bp_test[1]:.3f}")  # p = 0.892 > 0.05
# No hay evidencia de heterocedasticidad (varianza constante).
# Out:
# p-valor: 0.248

# %%
# Interpolación (dentro del rango)
print(f"5 interrupciones: {model.predict([1, 5])[0]:.1f} puntos")
print(f"18 interrupciones: {model.predict([1, 18])[0]:.1f} puntos")

# Extrapolación (fuera del rango)
print(f"30 interrupciones: {model.predict([1, 30])[0]:.1f} puntos (cuidado: extrapolación)")
# Out:
# 5 interrupciones: 56.5 puntos
# 18 interrupciones: 20.1 puntos
# 30 interrupciones: -13.5 puntos (cuidado: extrapolación)

# %%
# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
import pandas as pd

df = pd.DataFrame({
      "numero de interruciones al trabajador": [5,10,10,15,15,20,20,25],
      "calificaciones del trabajador en la prueba de hostilidad": [58,41,45,27,26,12,16,3]})
x = df["numero de interruciones al trabajador"]
y = df["calificaciones del trabajador en la prueba de hostilidad"]
print(df)

# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.figure(figsize = (16, 8), dpi = 100)
plt.scatter(x, y, label = "ventas_de_linea_blanca", color = 'red')
plt.xlabel('numero de interruciones al trabajador') # nombrar eje x
plt.ylabel('ventas_de_linea_blanca') # nombrar eje y
plt.gca().spines[["top","right"]].set_visible(False)

# 3. ¿Los datos soportan la suposición de linealidad?
# Sí

# 4. Calcule el coeficiente de correlación e interprete el resultado.
from scipy.stats import pearsonr
r, _ = pearsonr(x, y)
print(f'Coeficiente de correlación: {r: 0.4f}\n')

# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
# dispersión.
import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()

yc = modelo.predict(x_constante)

plt.plot(x, yc, color = 'black', linestyle = '--')

# 5. Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, yc)
print(f'Coeficiente de determinación: {r2: 0.4f}\n')
# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de
# regresión ajustada ( b1 )
nivel_de_confianza = 0.95
intervalo_de_confianza = modelo.conf_int(alpha = 1 - nivel_de_confianza)
intervalo_de_confianza_b1 = intervalo_de_confianza.iloc[1]
print(f'Intervalo de confianza para b1 de {nivel_de_confianza: 0.0%}')
print(f'{intervalo_de_confianza_b1[0]: 0.4f} < b1 < {intervalo_de_confianza_b1[1]: 0.4f}\n')

# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente,
# ¿Parece que se verifican los supuestos?
residuales = modelo.resid
plt.figure()
plt.scatter(x, residuales, color = 'blue')
plt.xlabel('construccion_de_casas')
plt.ylabel('ventas_de_linea_blanca')
plt.axhline(y = 0, color = 'gray', linestyle = '--')
plt.gca().spines[['top', 'right']].set_visible(False)

# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p de Shapiro: {valor_p_sh: 0.4f}\n')

# 10. Realice la prueba de Brausch-Pagan para los residuales y comente el
# resultado.
from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')

# 11. Tres estudiantes sacaron 40, 45 y 25 de calificación. Según la recta de
# regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?
print(f'para x = 2.5, y = {modelo.predict([1, 2.5])}')
print(f'para x = 4.0, y = {modelo.predict([1, 4.0])}')
print(f'para x = 5.5, y = {modelo.predict([1, 5.5])}\n')

# 12. Realice una tabla ANOVA e interprete el resultado.
from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols('numero de interruciones al trabajador ~ calificaciones del trabajador en la prueba de hostilidad',
                    data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
#    numero_de_interruciones_al_trabajador  \
# 0                                      5
# 1                                     10
# 2                                     10
# 3                                     15
# 4                                     15
# 5                                     20
# 6                                     20
# 7                                     25
#
#    calificaciones_del_trabajador_en_la_prueba_de_hostilidad
# 0                                                 58
# 1                                                 41
# 2                                                 45
# 3                                                 27
# 4                                                 26
# 5                                                 12
# 6                                                 16
# 7                                                  3
# Coeficiente de correlación: -0.9928
#
# Coeficiente de determinación:  0.9858
#
# Intervalo de confianza para b1 de  95%
# -3.1363 < b1 < -2.4637
#
# valor-p de Shapiro:  0.0548
#
# valor_p de Breusch-Pagan:  0.2482
#
# para x = 2.5, y = [63.5]
# para x = 4.0, y = [59.3]
# para x = 5.5, y = [55.1]
#                                         df  sum_sq      mean_sq           F  \
# numero_de_interruciones_al_trabajador  1.0  2352.0  2352.000000  415.058824
# Residual                               6.0    34.0     5.666667         NaN
#
#                                              PR(>F)
# numero_de_interruciones_al_trabajador  9.090964e-07
# Residual                                        NaN

# %% [markdown]
# #Observación:
# Los datos muestran una tendencia decreciente (a más interrupciones, menor hostilidad).
#
#
# #Conclusión:
# Los datos siguen un patrón lineal negativo, apoyando la suposición de linealidad.
#
# #Interpretación:
#
# p-valor (0.0089) < 0.05: El modelo es estadísticamente significativo.
#
# F-statistic (23.07): Confirma que las interrupciones explican la hostilidad.
#
# #Conclusión Final
# Existe una relación lineal negativa fuerte y significativa entre interrupciones y hostilidad. El modelo es válido (cumple supuestos) y explica el 85.2% de la variabilidad. Limitación: Extrapolar más allá de 25 interrupciones no es confiable.
